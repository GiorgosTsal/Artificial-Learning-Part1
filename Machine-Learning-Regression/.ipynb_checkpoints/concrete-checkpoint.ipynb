# %%
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
df= pd.read_csv('Concrete_Data.csv')
df.columns= ["Cement", "Blast Furnace Slag", "Fly Ash", "Water", "Superplasticizer", "Coarse Aggregate", "Fine Aggregate", "Age", "Concrete compressive strength"]
df.head(10)
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      332.5               142.5      0.0  228.0               0.0
# 2      332.5               142.5      0.0  228.0               0.0
# 3      198.6               132.4      0.0  192.0               0.0
# 4      266.0               114.0      0.0  228.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1024   276.4               116.0     90.3  179.6               8.9
# 1025   322.2                 0.0    115.6  196.0              10.4
# 1026   148.5               139.4    108.6  192.7               6.1
# 1027   159.1               186.7      0.0  175.6              11.3
# 1028   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Concrete compressive strength
# 0               1055.0           676.0   28                          61.89
# 1                932.0           594.0  270                          40.27
# 2                932.0           594.0  365                          41.05
# 3                978.4           825.5  360                          44.30
# 4                932.0           670.0   90                          47.03
# ...                ...             ...  ...                            ...
# 1024             870.1           768.3   28                          44.28
# 1025             817.9           813.4   28                          31.18
# 1026             892.4           780.0   28                          23.70
# 1027             989.6           788.9   28                          32.77
# 1028             864.5           761.5   28                          32.40
#
# [1029 rows x 9 columns]

# %%
for i in range(df.shape[1]-1):
    plt.plot(dataset[dataset.columns[i]],df[df.columns[df.shape[1]-1]],'x')
    plt.xlabel(df.columns[i])
    plt.ylabel("Feature " + str(i))
    plt.grid()
    plt.show()

# %%
x = df.drop('Concrete compressive strength', axis=1)
y = df.iloc[:,-1]
print(y)
print(x)
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3)
# Out:
# 0       61.89
# 1       40.27
# 2       41.05
# 3       44.30
# 4       47.03
#         ...
# 1024    44.28
# 1025    31.18
# 1026    23.70
# 1027    32.77
# 1028    32.40
# Name: Concrete compressive strength, Length: 1029, dtype: float64
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      332.5               142.5      0.0  228.0               0.0
# 2      332.5               142.5      0.0  228.0               0.0
# 3      198.6               132.4      0.0  192.0               0.0
# 4      266.0               114.0      0.0  228.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1024   276.4               116.0     90.3  179.6               8.9
# 1025   322.2                 0.0    115.6  196.0              10.4
# 1026   148.5               139.4    108.6  192.7               6.1
# 1027   159.1               186.7      0.0  175.6              11.3
# 1028   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age
# 0               1055.0           676.0   28
# 1                932.0           594.0  270
# 2                932.0           594.0  365
# 3                978.4           825.5  360
# 4                932.0           670.0   90
# ...                ...             ...  ...
# 1024             870.1           768.3   28
# 1025             817.9           813.4   28
# 1026             892.4           780.0   28
# 1027             989.6           788.9   28
# 1028             864.5           761.5   28
#
# [1029 rows x 8 columns]
